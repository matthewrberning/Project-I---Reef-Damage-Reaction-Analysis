# %%
import requests
from pprint import pprint
import time
import objectpath
import json
#from config import api_key

api_key = "3c3fedda5faa4fedbd69212bbb25f112"

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"


#http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=romney&facet_field=day_of_week&begin_date=20120101&end_date=20120101&api-key=####

date = "20100101"
date1 = "20110202"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-73-5bb58c17605d> in <module>()
#       2 from pprint import pprint
#       3 import time
# ----> 4 import objectpath
#       5 import json
#       6 #from config import api_key
#
# ModuleNotFoundError: No module named 'objectpath'

# %%
query = "coral bleaching"

# %%
 # Build query URL
query_url = url + "api-key=" + api_key + "&q=" + query + "&begin_date=" + date + "&end_date=" + date1
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=3c3fedda5faa4fedbd69212bbb25f112&q=coral bleaching&begin_date=20100101&end_date=20110202'

# %%
# Request articles

#articles = api.search( q = 'terrorist attack', page=1)


articles = requests.get(query_url).json()
articles

# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = [article for article in articles["response"]["docs"]]
pprint(articles_list)
# Out:
# [{'_id': '4fd39e328eb7c8105d8e0895',
#   'abstract': 'Coral reefs were severely damaged by elevated sea temperatures '
#               'last year.',
#   'blog': {},
#   'byline': {'organization': None,
#              'original': 'By JOHN COLLINS RUDOLF',
#              'person': [{'firstname': 'John',
#                          'lastname': 'RUDOLF',
#                          'middlename': 'Collins',
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'blogpost',
#   'headline': {'content_kicker': None,
#                'kicker': 'Green',
#                'main': 'Coral Bleaching Prompts Thailand to Close Diving Sites',
#                'name': None,
#                'print_headline': None,
#                'seo': None,
#                'sub': None},
# ...

# %%
 # Print the web_url of each stored article
print("Your Reading List")
for article in articles_list:
    print(article["web_url"])
# Out:
# Your Reading List
# https://green.blogs.nytimes.com/2011/01/21/thailand-closes-diving-sites-to-protect-corals/
# https://green.blogs.nytimes.com/2010/10/06/bleaching-hits-caribbean-corals/
# https://www.nytimes.com/2010/09/21/science/earth/21coral.html
# https://green.blogs.nytimes.com/2010/08/19/warming-seas-threaten-coral-off-indonesia/
# https://green.blogs.nytimes.com/2010/08/19/warming-seas-threaten-coral-off-indonesia/
# https://scientistatwork.blogs.nytimes.com/2010/08/10/nudibranchs-corals-and-readers-questions/
# https://green.blogs.nytimes.com/2010/12/10/2010-on-pace-to-be-warmest-on-record-nasa-says/
# https://dotearth.blogs.nytimes.com/2010/02/18/corals-partner-up-with-heat-resistant-algae/
# https://query.nytimes.com/gst/fullpage.html?res=9905E1DD163DF93BA15750C0A9669D8B63
# https://query.nytimes.com/gst/fullpage.html?res=9C05E1D61E38F932A35755C0A9669D8B63

# %%
# BONUS: How would we get 30 results?
# HINT: Look up the page query param

# Emply list for articles
articles_list = []

# loop through pages 0-2
for page in range(0, 10):
    query_url = f"{url}api-key=3c3fedda5faa4fedbd69212bbb25f112&q=coral-bleaching&begin_date=20100101&end_date=20110101"
   # create query with page number
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()

   # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
   # loop through the response and append each article to the list
    for article in articles["response"]["docs"]:
        articles_list.append(article)

# %%
#for article in articles_list:
 #   print(f'A snippet from the article: {article["snippet"]}')
    
articles_list = [article for article in articles["response"]["docs"]]
pprint(articles_list)
# Out:
# [{'_id': '541b022938f0d8296cb0ef69',
#   'blog': {},
#   'byline': {'organization': None,
#              'original': 'By DAMIEN CAVE  and CATHARINE SKIPP',
#              'person': [{'firstname': 'Damien',
#                          'lastname': 'CAVE',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Catharine',
#                          'lastname': 'SKIPP',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
# ...

# %%
#idr = []
#headline = []
#pub_date = []
#word_count = []
no_article= arr[0:100,17]
for number in no_article:
    
    id_data= articles_list['response'][]
    


#for ids in id_data:
    #target_url = url + id_data
    
id_data
# Out:
# '541b022938f0d8296cb0ef69'

# %%
# Get country information in JSON format
headline_response = requests.get(f"{url}headlines?format={format}").json()

# First element is general information, second is countries themselves
headlines = headline[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f49b55209834> in <module>()
#       3
#       4 # First element is general information, second is countries themselves
# ----> 5 headlines = headline[1]
#
# NameError: name 'headline' is not defined

# %%
for headline in headlines:
    print(headline["name"])

# %%
url2 = "http://api.nytimes.com/svc/search/v1/article?format=json&query=coral&begin_date=20100101&end_date=20100202&api-key=3c3fedda5faa4fedbd69212bbb25f112"
url2
# Out:
# 'http://api.nytimes.com/svc/search/v1/article?format=json&query=coral&begin_date=20100101&end_date=20100202&api-key=3c3fedda5faa4fedbd69212bbb25f112'

# %%
query2 = "coral bleaching"
offset = 1

# %%
# Request articles
articles2 = requests.get(url2).json()
articles2

# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = [article for article in articles2["response"]["docs"]]
pprint(articles_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-8ee976acbaba> in <module>()
#       5 # The "response" property in articles contains the actual articles
#       6 # list comprehension.
# ----> 7 articles_list = [article for article in articles2["response"]["docs"]]
#       8 pprint(articles_list)
#
# KeyError: 'response'

# %%
offset=1
